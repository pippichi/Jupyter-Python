# %%
import random
import string
import re

class Demo():
    def __init__(self):
        self.seeds = "1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()_+=-"
        self.seedslength = len(self.seeds)
        self.pattern1 = re.compile('[0-9]+')
        self.pattern2 = re.compile('[a-zA-Z]+')
        self.password_str = ""
    
    def __str__(self):
        if self.password_str == "":
            return "Please use function generate() to generate password!"
        else:
            return "generated password: "+self.password_str
    
    def isEmpty(self,lists):
        if len(lists) == 0:
            return True
        else:
            return False

    def generate(self):
        password_list = []
        match1 = []
        match2 = []
        while(isEmpty(match1) and isEmpty(match2)):
            for i in range(random.randint(10,self.seedslength)):
                password_list.append(random.choice(self.seeds))
            match1 = self.pattern1.findall(''.join(password_list))
            match2 = self.pattern2.findall(''.join(password_list))
        self.password_str = ''.join(password_list)

# %%
demo = Demo()
print(demo)
demo.generate()
print(demo)
# Out:
# Please use function generate() to generate password!
# generated password: 3yP5-8)hT=M3xZWOd

# %%
from random import choice
class Randomwalk ():
    def __init__(self,num_point=100):
        self.num_point = num_point
        self.x_lab = [0]
        self.y_lab = [0]
    def fill_walk(self):
        while len(self.x_lab) < self.num_point:
            x_direction = choice([1,-1])
            x_distance = choice([0,1,2,3,4])
            x_step = x_direction * x_distance
            y_direction = choice([1,-1])
            y_distance = choice([0,1,2,3,4])
            y_step = y_direction * y_distance
            if x_step == 0 and y_step == 0:
                continue
            next_x = self.x_lab[-1] + x_step
            next_y = self.y_lab[-1] + y_step
            self.x_lab.append(next_x)
            self.y_lab.append(next_y)

# %%
randomwalk = Randomwalk()
randomwalk.fill_walk()
randomwalk.x_lab
# Out:
# [0,
#  -2,
#  -4,
#  -4,
#  -3,
#  -1,
#  2,
#  4,
#  8,
#  5,
#  4,
#  1,
#  -1,
#  2,
#  3,
#  4,
#  4,
#  4,
#  4,
#  1,
#  -1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  2,
#  5,
#  4,
#  3,
#  3,
#  1,
#  5,
#  2,
#  2,
#  1,
#  3,
#  -1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  6,
#  7,
#  3,
#  -1,
#  3,
#  3,
#  1,
#  -1,
#  2,
#  5,
#  2,
#  0,
#  -3,
#  1,
#  -3,
#  -5,
#  -9,
#  -5,
#  -4,
#  -5,
#  -6,
#  -3,
#  -7,
#  -10,
#  -10,
#  -13,
#  -13,
#  -16,
#  -19,
#  -19,
#  -19,
#  -21,
#  -18,
#  -14,
#  -14,
#  -13,
#  -13,
#  -9,
#  -7,
#  -11,
#  -7,
#  -9,
#  -11,
#  -11,
#  -12,
#  -9,
#  -11,
#  -7,
#  -5,
#  -3,
#  -6,
#  -4,
#  -6,
#  -2,
#  -2,
#  -2,
#  0,
#  -1,
#  1,
#  -1,
#  2,
#  2,
#  2,
#  0,
#  -4,
#  -1,
#  -1,
#  -1,
#  3,
#  0,
#  0,
#  2,
#  2,
#  0,
#  -4,
#  -4,
#  0,
#  1,
#  -3,
#  1,
#  -2,
#  -4,
#  -7,
#  -3,
#  -2,
#  0,
#  -3,
#  -2,
#  2,
#  1,
#  -2,
#  -2,
#  0,
#  -2,
#  -2,
#  -3,
#  -1,
#  0,
#  0,
#  1,
#  -1,
#  0,
#  -3,
#  -6,
#  -4,
#  -2,
#  0,
# ...

# %%
x = 1
y = True if x!=1 else False
y
# Out:
# False
